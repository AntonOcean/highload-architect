# %%
from parse_docker_stats import *

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ds = DockerStats("../data.csv")

# %%
ds.mean_for_apps()
# Out:
#                                CPU %  MEM %  MEM Usage  PID  NET INPUT  \
# NAME
# highload-architect-backend-1    0.00   0.39      15.30  8.0       0.00
# highload-architect-db-1         0.20   0.35      13.78  9.0       0.01
# highload-architect-db-slave-1   0.34   0.24       9.33  6.0       0.85
#
#                                NET OUTPUT  BLOCK INPUT  BLOCK OUTPUT
# NAME
# highload-architect-backend-1         0.00          0.0          0.00
# highload-architect-db-1              0.86          0.0          0.40
# highload-architect-db-slave-1        0.00          0.0          1.27

# %%
ds.plot_category('MEM Usage')

# %%
ds.plot_category_all()
