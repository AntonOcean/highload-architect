# %%
from parse_docker_stats import *

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ds = DockerStats("../data.csv")

# %%
ds.mean_for_apps()
# Out:
#                                CPU %  MEM %  MEM Usage    PID  NET INPUT  \
# NAME
# highload-architect-backend-1  146.86   0.74      29.19  10.20       0.84
# highload-architect-pg-0-1       9.75  22.32     878.50  16.17     781.42
# highload-architect-pg-1-1       8.38   6.23     245.31  13.67     860.80
# highload-architect-pg-2-1       5.34   5.89     231.74  11.03     891.60
# highload-architect-pgpool-1     5.63   4.46     175.44  38.33     648.63
#
#                               NET OUTPUT  BLOCK INPUT  BLOCK OUTPUT
# NAME
# highload-architect-backend-1        0.97         8.71          0.00
# highload-architect-pg-0-1        1834.17        21.40       3085.00
# highload-architect-pg-1-1          16.58        21.63       3144.00
# highload-architect-pg-2-1           4.61        23.93       3203.67
# highload-architect-pgpool-1       939.43         4.67          1.67

# %%
ds.plot_category('MEM Usage')

# %%
ds.plot_category_all()
