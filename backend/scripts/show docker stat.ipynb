# %%
from parse_docker_stats import *

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ds = DockerStats("data.csv")

# %%
ds.mean_for_apps()
# Out:
#                                CPU %  MEM %  MEM Usage  PID  NET INPUT  \
# NAME
# highload-architect-backend-1     0.0   0.39      15.45  9.0       0.00
# highload-architect-db-1          0.0   0.48      18.84  9.0       0.28
# highload-architect-db-slave-1    0.3   0.36      14.28  6.0       1.84
#
#                                NET OUTPUT  BLOCK INPUT  BLOCK OUTPUT
# NAME
# highload-architect-backend-1         0.00          0.0          0.00
# highload-architect-db-1              3.61          0.0          4.48
# highload-architect-db-slave-1        0.18          0.0          1.59

# %%
ds.plot_category('MEM Usage')

# %%
ds.plot_category_all()
